# %%
import json
import os

# %%
def verify_github_repos(username):
  repos_filename = f"repos_{username}.json"
  final_filename = f"final_{username}.json"

  with open(repos_filename, "r", encoding="utf-8") as f:
    source_repos = json.load(f)

  with open(final_filename, "r", encoding="utf-8") as f:
    final_data = json.load(f)

  source_names = {repo.get('name') for repo in source_repos}
  final_names = set()

  print("Repositories per category:")
  for category, repos in final_data.items():
    count = len(repos)
    print(f"{category}: {count}")
    for repo in repos:
      final_names.add(repo.get('current_name'))

  missing_repos = source_names - final_names

  if missing_repos:
    print("\nMissing repositories:")
    for name in missing_repos:
      print(name)
  else:
    print(f"\nAll repositories are present in the final file. Total count: {len(source_names)}")

  print("\nLocal Repository Validation:")
  for category, repos in final_data.items():
    for repo in repos:
      name = repo.get('current_name')
      local_path = repo.get('local_repository')

      folder_exists = False
      git_exists = False
      path_display = "Folder not defined"

      if local_path:
        path_display = local_path
        if os.path.isdir(local_path):
          folder_exists = True
          if os.path.isdir(os.path.join(local_path, ".git")):
            git_exists = True

      folder_emoji = "✅" if folder_exists else "❌"
      git_emoji = "✅" if git_exists else "❌"

      print(f"{name} - {path_display} - Folder exist {folder_emoji}, .git exist {git_emoji}")

# %%
verify_github_repos("k26rahul")
# Out:
# Repositories per category:
# hackathons: 8
# web_development: 20
# machine_learning: 8
# dsa: 5
# iitm: 22
# others: 4
#
# All repositories are present in the final file. Total count: 67
#
# Local Repository Validation:
# AI-Agent-Hackathon - C:\k26rahul\Code\GitHub\Hackathons\AI-Agent-Hackathon - Folder exist ✅, .git exist ✅
# cricket-hackathon-2023 - C:\k26rahul\Code\GitHub\Hackathons\IITM-Cricket-Hackathon-2023 - Folder exist ✅, .git exist ✅
# Space-Hackathon - C:\k26rahul\Code\GitHub\Hackathons\Space-Hackathon - Folder exist ✅, .git exist ✅
# Microsoft-AI-Odyssey - C:\k26rahul\Code\GitHub\Hackathons\Microsoft-AI-Odyssey - Folder exist ✅, .git exist ✅
# StudyMate - C:\k26rahul\Code\GitHub\Hackathons\StudyMate - Folder exist ✅, .git exist ✅
# RythmFit-Hack-O-Pitch-2.0 - C:\k26rahul\Code\GitHub\Hackathons\RythmFit-Hack-O-Pitch-2.0 - Folder exist ✅, .git exist ✅
# Violence-Detection - C:\k26rahul\Code\GitHub\Hackathons\Violence-Detection - Folder exist ✅, .git exist ✅
# PixelMind-AI - C:\k26rahul\Code\GitHub\Hackathons\PixelMind-AI - Folder exist ✅, .git exist ✅
# ai-dungeon - C:\k26rahul\Code\GitHub\Web-Development\ai-dungeon - Folder exist ✅, .git exist ✅
# auth-practice - C:\k26rahul\Code\GitHub\Web-Development\auth-practice - Folder exist ✅, .git exist ✅
# BS-Grade-Calculator - C:\k26rahul\Code\GitHub\Web-Development\BS-Grade-Calculator - Folder exist ✅, .git exist ✅
# event-emitter-lib - C:\k26rahul\Code\GitHub\Web-Development\event-emitter-lib - Folder exist ✅, .git exist ✅
# Expense-Tracker-React - C:\k26rahul\Code\GitHub\Web-Development\Expense-Tracker-React - Folder exist ✅, .git exist ✅
# HTML-Projects - C:\k26rahul\Code\GitHub\Web-Development\HTML-Projects - Folder exist ✅, .git exist ✅
# inventory-management-app - C:\k26rahul\Code\GitHub\Web-Development\inventory-management-app - Folder exist ✅, .git exist ✅
# js-projects - C:\k26rahul\Code\GitHub\Web-Development\js-projects - Folder exist ✅, .git exist ✅
# js-projects-2 - C:\k26rahul\Code\GitHub\Web-Development\js-projects-2 - Folder exist ✅, .git exist ✅
# poetry-app - C:\k26rahul\Code\GitHub\Web-Development\poetry-app - Folder exist ✅, .git exist ✅
# poster-catalogue - C:\k26rahul\Code\GitHub\Web-Development\poster-catalogue - Folder exist ✅, .git exist ✅
# PostgreSQL-FastAPI-Test - C:\k26rahul\Code\GitHub\Web-Development\PostgreSQL-FastAPI-Test - Folder exist ✅, .git exist ✅
# Learning-React - C:\k26rahul\Code\GitHub\Web-Development\Learning-React - Folder exist ✅, .git exist ✅
# React-Egghead - C:\k26rahul\Code\GitHub\Web-Development\React-Egghead - Folder exist ✅, .git exist ✅
# t3-vanilla-js-2025 - C:\k26rahul\Code\GitHub\Web-Development\t3-vanilla-js-2025 - Folder exist ✅, .git exist ✅
# Tic-Tac-Toe-React - C:\k26rahul\Code\GitHub\Web-Development\Tic-Tac-Toe-React - Folder exist ✅, .git exist ✅
# Tic-Tac-Toe-Vanilla-JS - C:\k26rahul\Code\GitHub\Web-Development\Tic-Tac-Toe-Vanilla-JS - Folder exist ✅, .git exist ✅
# vectors - C:\k26rahul\Code\GitHub\Web-Development\vectors - Folder exist ✅, .git exist ✅
# vishnu-story - C:\k26rahul\Code\GitHub\Web-Development\vishnu-story - Folder exist ✅, .git exist ✅
# Weather-App-React - C:\k26rahul\Code\GitHub\Web-Development\Weather-App-React - Folder exist ✅, .git exist ✅
# Boston-Housing-Price-Prediction - C:\k26rahul\Code\GitHub\Machine-Learning\Boston-Housing-Price-Prediction - Folder exist ✅, .git exist ✅
# Deep-Learning-March-2024 - C:\k26rahul\Code\GitHub\Machine-Learning\Deep-Learning-March-2024 - Folder exist ✅, .git exist ✅
# Machine-Learning-April-2023 - C:\k26rahul\Code\GitHub\Machine-Learning\Machine-Learning-April-2023 - Folder exist ✅, .git exist ✅
# Machine-Learning-Kylie-Ying - C:\k26rahul\Code\GitHub\Machine-Learning\Machine-Learning-Kylie-Ying - Folder exist ✅, .git exist ✅
# ml-april-25 - C:\k26rahul\Code\GitHub\Machine-Learning\ml-april-25 - Folder exist ✅, .git exist ✅
# ML-Projects-March-2024 - C:\k26rahul\Code\GitHub\Machine-Learning\ML-Projects-March-2024 - Folder exist ✅, .git exist ✅
# ML-Projects-Siddhardhan - C:\k26rahul\Code\GitHub\Machine-Learning\ML-Projects-Siddhardhan - Folder exist ✅, .git exist ✅
# IPL2023-Powerplay-Score-Prediction - C:\k26rahul\Code\GitHub\Machine-Learning\IPL2023-Powerplay-Score-Prediction - Folder exist ✅, .git exist ✅
# Codeforces-December-Sanika - C:\k26rahul\Code\GitHub\DSA\Codeforces-December-Sanika - Folder exist ✅, .git exist ✅
# DSA-CP - C:\k26rahul\Code\GitHub\DSA\DSA-CP - Folder exist ✅, .git exist ✅
# DSA-Java-March-2024 - C:\k26rahul\Code\GitHub\DSA\DSA-Java-March-2024 - Folder exist ✅, .git exist ✅
# Java-Practice - C:\k26rahul\Code\GitHub\DSA\Java-Practice - Folder exist ✅, .git exist ✅
# Mosh-Ultimate-DSA-Java - C:\k26rahul\Code\GitHub\DSA\Mosh-Ultimate-DSA-Java - Folder exist ✅, .git exist ✅
# App-Dev-1 - C:\k26rahul\Code\GitHub\IITM\App-Dev-1 - Folder exist ✅, .git exist ✅
# appdev1-nextra - C:\k26rahul\Code\GitHub\IITM\appdev1-nextra - Folder exist ✅, .git exist ✅
# js-practice - C:\k26rahul\Code\GitHub\IITM\js-practice - Folder exist ✅, .git exist ✅
# Machine-Learning-IITM - C:\k26rahul\Code\GitHub\IITM\Machine-Learning-IITM - Folder exist ✅, .git exist ✅
# DBMS-Notes-December-2023 - C:\k26rahul\Code\GitHub\IITM\DBMS-Notes-December-2023 - Folder exist ✅, .git exist ✅
# DBMS-T1-2024 - C:\k26rahul\Code\GitHub\IITM\IITM-DBMS-T1-2024 - Folder exist ✅, .git exist ✅
# DBMS-T2-2024 - C:\k26rahul\Code\GitHub\IITM\DBMS-T2-2024 - Folder exist ✅, .git exist ✅
# household-services-rahul - C:\k26rahul\Code\GitHub\IITM\household-services-rahul - Folder exist ✅, .git exist ✅
# household-services-skeleton - C:\k26rahul\Code\GitHub\IITM\household-services-skeleton - Folder exist ✅, .git exist ✅
# household-services-vidhatri - C:\k26rahul\Code\GitHub\IITM\household-services-vidhatri - Folder exist ✅, .git exist ✅
# mad1-skeleton - C:\k26rahul\Code\GitHub\IITM\mad1-skeleton - Folder exist ✅, .git exist ✅
# mad2-project-rahul - C:\k26rahul\Code\GitHub\IITM\mad2-project-rahul - Folder exist ✅, .git exist ✅
# mad2-project-vidu - C:\k26rahul\Code\GitHub\IITM\mad2-project-vidu - Folder exist ✅, .git exist ✅
# Java-T1-2024 - C:\k26rahul\Code\GitHub\IITM\IITM-Java-T1-2024 - Folder exist ✅, .git exist ✅
# java-t1-2025 - C:\k26rahul\Code\GitHub\IITM\java-t1-2025 - Folder exist ✅, .git exist ✅
# Java-T2-2025 - C:\k26rahul\Code\GitHub\IITM\Java-T2-2025 - Folder exist ✅, .git exist ✅
# PDSA-T1-2024 - C:\k26rahul\Code\GitHub\IITM\IITM-PDSA-T1-2024 - Folder exist ✅, .git exist ✅
# PDSA-T2-2024 - C:\k26rahul\Code\GitHub\IITM\PDSA-T2-2024 - Folder exist ✅, .git exist ✅
# Python-T2-2023-Rahul - C:\k26rahul\Code\GitHub\IITM\Python-T2-2023-Rahul - Folder exist ✅, .git exist ✅
# Python-T1-2024-Vidhatri - C:\k26rahul\Code\GitHub\IITM\Python-T1-2024-Vidhatri - Folder exist ✅, .git exist ✅
# OPPE1-November-2023 - C:\k26rahul\Code\GitHub\IITM\OPPE1-November-2023 - Folder exist ✅, .git exist ✅
# OPPE2-December-2023 - C:\k26rahul\Code\GitHub\IITM\OPPE2-December-2023 - Folder exist ✅, .git exist ✅
# k26rahul - C:\k26rahul\Code\GitHub\Others\k26rahul - Folder exist ✅, .git exist ✅
# playground-2024 - C:\k26rahul\Code\GitHub\Others\playground-2024 - Folder exist ✅, .git exist ✅
# playground-2025 - C:\k26rahul\Code\GitHub\Others\playground-2025 - Folder exist ✅, .git exist ✅
# yt-channel-dl - C:\k26rahul\Code\GitHub\Others\yt-channel-dl - Folder exist ✅, .git exist ✅

# %%
verify_github_repos("vidhatrihr")
# Out:
# Repositories per category:
# web_development: 7
# machine_learning: 1
# dsa: 1
# iitm: 9
# others: 2
#
# All repositories are present in the final file. Total count: 20
#
# Local Repository Validation:
# auth-practice - C:\vidhatrihr\Code\auth-practice - Folder exist ❌, .git exist ❌
# HTML-Projects - C:\vidhatrihr\Code\Github\HTML-Projects - Folder exist ❌, .git exist ❌
# inventory-management-app - C:\vidhatrihr\Code\inventory-management-app - Folder exist ❌, .git exist ❌
# js-projects - C:\vidhatrihr\Code\Github\js-projects - Folder exist ❌, .git exist ❌
# js-projects-2 - C:\vidhatrihr\Code\Github\js-projects-2 - Folder exist ❌, .git exist ❌
# poetry-app - C:\vidhatrihr\Code\Github\flask-apps\poetry-app - Folder exist ❌, .git exist ❌
# gutenberg-library - C:\vidhatrihr\Code\Github\flask-apps\gutenberg-library - Folder exist ❌, .git exist ❌
# machine-learning - C:\vidhatrihr\Code\Github\machine-learning - Folder exist ❌, .git exist ❌
# Codeforces - C:\vidhatrihr\Code\Codeforces - Folder exist ❌, .git exist ❌
# App-Dev-1 - C:\vidhatrihr\Code\Github\App-Dev-1 - Folder exist ❌, .git exist ❌
# js-practice - C:\vidhatrihr\Code\Github\js-practice - Folder exist ❌, .git exist ❌
# household-services - C:\vidhatrihr\Code\Github\household-services - Folder exist ❌, .git exist ❌
# mad2-project - Folder not defined - Folder exist ❌, .git exist ❌
# ML-IITM - C:\vidhatrihr\Code\Github\ML-IITM - Folder exist ❌, .git exist ❌
# DBMS-T2-2024 - C:\vidhatrihr\Code\Github\DBMS-T2-2024 - Folder exist ❌, .git exist ❌
# PDSA-T2-2024 - C:\vidhatrihr\Code\Github\PDSA-T2-2024 - Folder exist ❌, .git exist ❌
# Python - C:\vidhatrihr\Code\Github\Python - Folder exist ❌, .git exist ❌
# Java-T2-2025 - C:\vidhatrihr\Code\Github\Java-T2-2025 - Folder exist ❌, .git exist ❌
# Playground - C:\vidhatrihr\Code\Github\Playground - Folder exist ❌, .git exist ❌
# vidhatrihr - C:\vidhatrihr\Code\Github\vidhatrihr - Folder exist ❌, .git exist ❌
