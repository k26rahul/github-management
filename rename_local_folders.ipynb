# %%
import json
import os
import shutil

# %%
def rename_local_folders(json_filename, dry_run=True):
  # 1. Header Display
  mode_text = "DRY RUN (No changes will be made)" if dry_run else "LIVE MODE (Committing changes)"
  print("=" * 50)
  print(f"MODE: {mode_text}")
  print("=" * 50)

  with open(json_filename, 'r', encoding='utf-8') as f:
    data = json.load(f)

  # This dictionary will store the { "new_name": "new_local_path" } mapping
  new_mapping = {}

  for category, repos in data.items():
    print(f"\n--- Category: {category} ---")
    for entry in repos:
      old_path = entry.get('local_repository')
      new_name = entry.get('new_name')

      if not old_path or not new_name:
        continue

      # Get the parent directory and construct the new path
      parent_dir = os.path.dirname(old_path)
      new_path = os.path.join(parent_dir, new_name)

      # Add to our new mapping dictionary
      new_mapping[new_name] = new_path

      if dry_run:
        print(f"[WILL RENAME] {old_path} -> {new_path}")
      else:
        try:
          if os.path.exists(old_path):
            os.rename(old_path, new_path)
            print(f"✔ {old_path} -> {new_path}")
          else:
            print(f"✘ Skip (Not Found): {old_path}")
        except Exception as e:
          print(f"✘ Error renaming {old_path}: {e}")

  # 2. Generate the mapping JSON file
  mapping_filename = "repo_path_mapping.json"
  try:
    with open(mapping_filename, 'w', encoding='utf-8') as f_out:
      json.dump(new_mapping, f_out, indent=4)
    print(f"\n--- Mapping file generated: {mapping_filename} ---")
  except Exception as e:
    print(f"\n✘ Error saving mapping file: {e}")

  print("\nDone.")

# %%
rename_local_folders("final_k26rahul.json", dry_run=True)
# Out:
# ==================================================
# MODE: DRY RUN (No changes will be made)
# ==================================================
#
# --- Category: hackathons ---
# [WILL RENAME] C:\k26rahul\Code\GitHub\Hackathons\AI-Agent-Hackathon -> C:\k26rahul\Code\GitHub\Hackathons\ai-agent-hackathon
# [WILL RENAME] C:\k26rahul\Code\GitHub\Hackathons\IITM-Cricket-Hackathon-2023 -> C:\k26rahul\Code\GitHub\Hackathons\cricket-hackathon-2023
# [WILL RENAME] C:\k26rahul\Code\GitHub\Hackathons\Space-Hackathon -> C:\k26rahul\Code\GitHub\Hackathons\space-hackathon
# [WILL RENAME] C:\k26rahul\Code\GitHub\Hackathons\Microsoft-AI-Odyssey -> C:\k26rahul\Code\GitHub\Hackathons\microsoft-ai-odyssey
# [WILL RENAME] C:\k26rahul\Code\GitHub\Hackathons\StudyMate -> C:\k26rahul\Code\GitHub\Hackathons\studymate
# [WILL RENAME] C:\k26rahul\Code\GitHub\Hackathons\RythmFit-Hack-O-Pitch-2.0 -> C:\k26rahul\Code\GitHub\Hackathons\rythmfit-hack-o-pitch-2.0
# [WILL RENAME] C:\k26rahul\Code\GitHub\Hackathons\Violence-Detection -> C:\k26rahul\Code\GitHub\Hackathons\violence-detection-hackathon
# [WILL RENAME] C:\k26rahul\Code\GitHub\Hackathons\PixelMind-AI -> C:\k26rahul\Code\GitHub\Hackathons\pixelmind-ai-hackathon
#
# --- Category: web_development ---
# [WILL RENAME] C:\k26rahul\Code\GitHub\Web-Development\ai-dungeon -> C:\k26rahul\Code\GitHub\Web-Development\ai-rpg-chat
# [WILL RENAME] C:\k26rahul\Code\GitHub\Web-Development\auth-practice -> C:\k26rahul\Code\GitHub\Web-Development\auth-system-flask
# [WILL RENAME] C:\k26rahul\Code\GitHub\Web-Development\BS-Grade-Calculator -> C:\k26rahul\Code\GitHub\Web-Development\bs-grade-calculator
# [WILL RENAME] C:\k26rahul\Code\GitHub\Web-Development\event-emitter-lib -> C:\k26rahul\Code\GitHub\Web-Development\event-emitter-lib
# [WILL RENAME] C:\k26rahul\Code\GitHub\Web-Development\Expense-Tracker-React -> C:\k26rahul\Code\GitHub\Web-Development\expense-tracker-react
# [WILL RENAME] C:\k26rahul\Code\GitHub\Web-Development\HTML-Projects -> C:\k26rahul\Code\GitHub\Web-Development\html-projects
# [WILL RENAME] C:\k26rahul\Code\GitHub\Web-Development\inventory-management-app -> C:\k26rahul\Code\GitHub\Web-Development\inventory-management-system
# [WILL RENAME] C:\k26rahul\Code\GitHub\Web-Development\js-projects -> C:\k26rahul\Code\GitHub\Web-Development\js-projects
# [WILL RENAME] C:\k26rahul\Code\GitHub\Web-Development\js-projects-2 -> C:\k26rahul\Code\GitHub\Web-Development\js-projects-2
# [WILL RENAME] C:\k26rahul\Code\GitHub\Web-Development\poetry-app -> C:\k26rahul\Code\GitHub\Web-Development\poetrydb-flask-app
# [WILL RENAME] C:\k26rahul\Code\GitHub\Web-Development\poster-catalogue -> C:\k26rahul\Code\GitHub\Web-Development\poster-catalogue-app
# [WILL RENAME] C:\k26rahul\Code\GitHub\Web-Development\PostgreSQL-FastAPI-Test -> C:\k26rahul\Code\GitHub\Web-Development\fastapi-postgresql-basics
# [WILL RENAME] C:\k26rahul\Code\GitHub\Web-Development\Learning-React -> C:\k26rahul\Code\GitHub\Web-Development\react-egghead-course
# [WILL RENAME] C:\k26rahul\Code\GitHub\Web-Development\React-Egghead -> C:\k26rahul\Code\GitHub\Web-Development\react-egghead-course-2
# [WILL RENAME] C:\k26rahul\Code\GitHub\Web-Development\t3-vanilla-js-2025 -> C:\k26rahul\Code\GitHub\Web-Development\tic-tac-toe-vanilla-js-2025
# [WILL RENAME] C:\k26rahul\Code\GitHub\Web-Development\Tic-Tac-Toe-React -> C:\k26rahul\Code\GitHub\Web-Development\tic-tac-toe-react
# [WILL RENAME] C:\k26rahul\Code\GitHub\Web-Development\Tic-Tac-Toe-Vanilla-JS -> C:\k26rahul\Code\GitHub\Web-Development\tic-tac-toe-vanilla-js
# [WILL RENAME] C:\k26rahul\Code\GitHub\Web-Development\vectors -> C:\k26rahul\Code\GitHub\Web-Development\plotly-vector-visualizer
# [WILL RENAME] C:\k26rahul\Code\GitHub\Web-Development\vishnu-story -> C:\k26rahul\Code\GitHub\Web-Development\remotion-story-video
# [WILL RENAME] C:\k26rahul\Code\GitHub\Web-Development\Weather-App-React -> C:\k26rahul\Code\GitHub\Web-Development\weather-app-react
#
# --- Category: machine_learning ---
# [WILL RENAME] C:\k26rahul\Code\GitHub\Machine-Learning\Boston-Housing-Price-Prediction -> C:\k26rahul\Code\GitHub\Machine-Learning\boston-housing-price-prediction
# [WILL RENAME] C:\k26rahul\Code\GitHub\Machine-Learning\Deep-Learning-March-2024 -> C:\k26rahul\Code\GitHub\Machine-Learning\deep-learning-march-2024
# [WILL RENAME] C:\k26rahul\Code\GitHub\Machine-Learning\Machine-Learning-April-2023 -> C:\k26rahul\Code\GitHub\Machine-Learning\machine-learning-april-2023
# [WILL RENAME] C:\k26rahul\Code\GitHub\Machine-Learning\Machine-Learning-Kylie-Ying -> C:\k26rahul\Code\GitHub\Machine-Learning\machine-learning-kylie-ying
# [WILL RENAME] C:\k26rahul\Code\GitHub\Machine-Learning\ml-april-25 -> C:\k26rahul\Code\GitHub\Machine-Learning\machine-learning-april-2025
# [WILL RENAME] C:\k26rahul\Code\GitHub\Machine-Learning\ML-Projects-March-2024 -> C:\k26rahul\Code\GitHub\Machine-Learning\machine-learning-march-2024
# [WILL RENAME] C:\k26rahul\Code\GitHub\Machine-Learning\ML-Projects-Siddhardhan -> C:\k26rahul\Code\GitHub\Machine-Learning\ml-projects-siddhardhan
# [WILL RENAME] C:\k26rahul\Code\GitHub\Machine-Learning\IPL2023-Powerplay-Score-Prediction -> C:\k26rahul\Code\GitHub\Machine-Learning\ipl2023-powerplay-score-prediction
#
# --- Category: dsa ---
# [WILL RENAME] C:\k26rahul\Code\GitHub\DSA\Codeforces-December-Sanika -> C:\k26rahul\Code\GitHub\DSA\codeforces-december-2023
# [WILL RENAME] C:\k26rahul\Code\GitHub\DSA\DSA-CP -> C:\k26rahul\Code\GitHub\DSA\dsa-cp
# [WILL RENAME] C:\k26rahul\Code\GitHub\DSA\DSA-Java-March-2024 -> C:\k26rahul\Code\GitHub\DSA\dsa-java-march-2024
# [WILL RENAME] C:\k26rahul\Code\GitHub\DSA\Java-Practice -> C:\k26rahul\Code\GitHub\DSA\dsa-java-september-2024
# [WILL RENAME] C:\k26rahul\Code\GitHub\DSA\Mosh-Ultimate-DSA-Java -> C:\k26rahul\Code\GitHub\DSA\mosh-ultimate-dsa-java
#
# --- Category: iitm ---
# [WILL RENAME] C:\k26rahul\Code\GitHub\IITM\App-Dev-1 -> C:\k26rahul\Code\GitHub\IITM\mad1-coursework
# [WILL RENAME] C:\k26rahul\Code\GitHub\IITM\appdev1-nextra -> C:\k26rahul\Code\GitHub\IITM\mad1-course-website
# [WILL RENAME] C:\k26rahul\Code\GitHub\IITM\js-practice -> C:\k26rahul\Code\GitHub\IITM\mad2-coursework
# [WILL RENAME] C:\k26rahul\Code\GitHub\IITM\Machine-Learning-IITM -> C:\k26rahul\Code\GitHub\IITM\machine-learning-techniques
# [WILL RENAME] C:\k26rahul\Code\GitHub\IITM\DBMS-Notes-December-2023 -> C:\k26rahul\Code\GitHub\IITM\dbms-t3-2023
# [WILL RENAME] C:\k26rahul\Code\GitHub\IITM\IITM-DBMS-T1-2024 -> C:\k26rahul\Code\GitHub\IITM\dbms-t1-2024
# [WILL RENAME] C:\k26rahul\Code\GitHub\IITM\DBMS-T2-2024 -> C:\k26rahul\Code\GitHub\IITM\dbms-t2-2024
# [WILL RENAME] C:\k26rahul\Code\GitHub\IITM\household-services-rahul -> C:\k26rahul\Code\GitHub\IITM\mad1-project
# [WILL RENAME] C:\k26rahul\Code\GitHub\IITM\household-services-skeleton -> C:\k26rahul\Code\GitHub\IITM\mad1-project-skeleton
# [WILL RENAME] C:\k26rahul\Code\GitHub\IITM\household-services-vidhatri -> C:\k26rahul\Code\GitHub\IITM\mad1-project-prototype
# [WILL RENAME] C:\k26rahul\Code\GitHub\IITM\mad1-skeleton -> C:\k26rahul\Code\GitHub\IITM\flask-sqlalchemy-template
# [WILL RENAME] C:\k26rahul\Code\GitHub\IITM\mad2-project-rahul -> C:\k26rahul\Code\GitHub\IITM\mad2-project
# [WILL RENAME] C:\k26rahul\Code\GitHub\IITM\mad2-project-vidu -> C:\k26rahul\Code\GitHub\IITM\mad2-project-skeleton
# [WILL RENAME] C:\k26rahul\Code\GitHub\IITM\IITM-Java-T1-2024 -> C:\k26rahul\Code\GitHub\IITM\java-t1-2024
# [WILL RENAME] C:\k26rahul\Code\GitHub\IITM\java-t1-2025 -> C:\k26rahul\Code\GitHub\IITM\java-t1-2025
# [WILL RENAME] C:\k26rahul\Code\GitHub\IITM\Java-T2-2025 -> C:\k26rahul\Code\GitHub\IITM\java-t2-2025
# [WILL RENAME] C:\k26rahul\Code\GitHub\IITM\IITM-PDSA-T1-2024 -> C:\k26rahul\Code\GitHub\IITM\pdsa-t1-2024
# [WILL RENAME] C:\k26rahul\Code\GitHub\IITM\PDSA-T2-2024 -> C:\k26rahul\Code\GitHub\IITM\pdsa-t2-2024
# [WILL RENAME] C:\k26rahul\Code\GitHub\IITM\Python-T2-2023-Rahul -> C:\k26rahul\Code\GitHub\IITM\python-t2-2023
# [WILL RENAME] C:\k26rahul\Code\GitHub\IITM\Python-T1-2024-Vidhatri -> C:\k26rahul\Code\GitHub\IITM\python-t1-2024
# [WILL RENAME] C:\k26rahul\Code\GitHub\IITM\OPPE1-November-2023 -> C:\k26rahul\Code\GitHub\IITM\python-oppe1-t3-2023
# [WILL RENAME] C:\k26rahul\Code\GitHub\IITM\OPPE2-December-2023 -> C:\k26rahul\Code\GitHub\IITM\python-oppe2-t3-2023
#
# --- Category: others ---
# [WILL RENAME] C:\k26rahul\Code\GitHub\Others\k26rahul -> C:\k26rahul\Code\GitHub\Others\k26rahul
# [WILL RENAME] C:\k26rahul\Code\GitHub\Others\playground-2024 -> C:\k26rahul\Code\GitHub\Others\playground-2024
# [WILL RENAME] C:\k26rahul\Code\GitHub\Others\playground-2025 -> C:\k26rahul\Code\GitHub\Others\playground-2025
# [WILL RENAME] C:\k26rahul\Code\GitHub\Others\yt-channel-dl -> C:\k26rahul\Code\GitHub\Others\yt-channel-downloader
#
# --- Mapping file generated: repo_path_mapping.json ---
#
# Done.
