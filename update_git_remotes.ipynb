# %%
import json
import os
import subprocess

# %%
def update_git_remotes(mapping_filename, username="k26rahul", dry_run=True):
  # 1. Header Display
  mode_text = "DRY RUN (No changes will be made)" if dry_run else "LIVE MODE (Committing changes)"
  print("=" * 50)
  print(f"MODE: {mode_text}")
  print("=" * 50)

  # Load the mapping generated by the previous step
  with open(mapping_filename, 'r', encoding='utf-8') as f:
    mapping = json.load(f)

  for repo_name, local_path in mapping.items():
    # Construct the new GitHub URL
    new_url = f"https://github.com/k26rahul/{repo_name}.git"

    print(f"\nProcessing: {repo_name}")

    if not os.path.exists(local_path):
      print(f"  ✘ Path not found: {local_path}")
      continue

    if dry_run:
      print(f"  [WILL UPDATE] URL to: {new_url}")
      print(f"  [WILL EXECUTE] git remote set-url origin {new_url} inside {local_path}")
    else:
      try:
        # Run the git command inside the specific directory
        # 'cwd' stands for Current Working Directory
        subprocess.run(
            ["git", "remote", "set-url", "origin", new_url],
            cwd=local_path,
            check=True,
            capture_output=True,
            text=True
        )
        print(f"  ✔ Remote URL updated successfully.")

        # Verify the change
        verify = subprocess.run(
            ["git", "remote", "get-url", "origin"],
            cwd=local_path,
            capture_output=True,
            text=True
        )
        print(f"  → Current origin: {verify.stdout.strip()}")

      except subprocess.CalledProcessError as e:
        print(f"  ✘ Git Error in {repo_name}: {e.stderr.strip()}")
      except Exception as e:
        print(f"  ✘ Unexpected Error: {e}")

  print("\nAll remote URLs processed.")

# %%
update_git_remotes("repo_path_mapping.json", dry_run=True)
# Out:
# ==================================================
# MODE: DRY RUN (No changes will be made)
# ==================================================
#
# Processing: ai-agent-hackathon
#   [WILL UPDATE] URL to: https://github.com/k26rahul/ai-agent-hackathon.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/ai-agent-hackathon.git inside C:\k26rahul\Code\GitHub\Hackathons\ai-agent-hackathon
#
# Processing: cricket-hackathon-2023
#   [WILL UPDATE] URL to: https://github.com/k26rahul/cricket-hackathon-2023.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/cricket-hackathon-2023.git inside C:\k26rahul\Code\GitHub\Hackathons\cricket-hackathon-2023
#
# Processing: space-hackathon
#   [WILL UPDATE] URL to: https://github.com/k26rahul/space-hackathon.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/space-hackathon.git inside C:\k26rahul\Code\GitHub\Hackathons\space-hackathon
#
# Processing: microsoft-ai-odyssey
#   [WILL UPDATE] URL to: https://github.com/k26rahul/microsoft-ai-odyssey.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/microsoft-ai-odyssey.git inside C:\k26rahul\Code\GitHub\Hackathons\microsoft-ai-odyssey
#
# Processing: studymate
#   [WILL UPDATE] URL to: https://github.com/k26rahul/studymate.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/studymate.git inside C:\k26rahul\Code\GitHub\Hackathons\studymate
#
# Processing: rythmfit-hack-o-pitch-2.0
#   [WILL UPDATE] URL to: https://github.com/k26rahul/rythmfit-hack-o-pitch-2.0.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/rythmfit-hack-o-pitch-2.0.git inside C:\k26rahul\Code\GitHub\Hackathons\rythmfit-hack-o-pitch-2.0
#
# Processing: violence-detection-hackathon
#   [WILL UPDATE] URL to: https://github.com/k26rahul/violence-detection-hackathon.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/violence-detection-hackathon.git inside C:\k26rahul\Code\GitHub\Hackathons\violence-detection-hackathon
#
# Processing: pixelmind-ai-hackathon
#   [WILL UPDATE] URL to: https://github.com/k26rahul/pixelmind-ai-hackathon.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/pixelmind-ai-hackathon.git inside C:\k26rahul\Code\GitHub\Hackathons\pixelmind-ai-hackathon
#
# Processing: ai-rpg-chat
#   [WILL UPDATE] URL to: https://github.com/k26rahul/ai-rpg-chat.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/ai-rpg-chat.git inside C:\k26rahul\Code\GitHub\Web-Development\ai-rpg-chat
#
# Processing: auth-system-flask
#   [WILL UPDATE] URL to: https://github.com/k26rahul/auth-system-flask.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/auth-system-flask.git inside C:\k26rahul\Code\GitHub\Web-Development\auth-system-flask
#
# Processing: bs-grade-calculator
#   [WILL UPDATE] URL to: https://github.com/k26rahul/bs-grade-calculator.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/bs-grade-calculator.git inside C:\k26rahul\Code\GitHub\Web-Development\bs-grade-calculator
#
# Processing: event-emitter-lib
#   [WILL UPDATE] URL to: https://github.com/k26rahul/event-emitter-lib.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/event-emitter-lib.git inside C:\k26rahul\Code\GitHub\Web-Development\event-emitter-lib
#
# Processing: expense-tracker-react
#   [WILL UPDATE] URL to: https://github.com/k26rahul/expense-tracker-react.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/expense-tracker-react.git inside C:\k26rahul\Code\GitHub\Web-Development\expense-tracker-react
#
# Processing: html-projects
#   [WILL UPDATE] URL to: https://github.com/k26rahul/html-projects.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/html-projects.git inside C:\k26rahul\Code\GitHub\Web-Development\html-projects
#
# Processing: inventory-management-system
#   [WILL UPDATE] URL to: https://github.com/k26rahul/inventory-management-system.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/inventory-management-system.git inside C:\k26rahul\Code\GitHub\Web-Development\inventory-management-system
#
# Processing: js-projects
#   [WILL UPDATE] URL to: https://github.com/k26rahul/js-projects.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/js-projects.git inside C:\k26rahul\Code\GitHub\Web-Development\js-projects
#
# Processing: js-projects-2
#   [WILL UPDATE] URL to: https://github.com/k26rahul/js-projects-2.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/js-projects-2.git inside C:\k26rahul\Code\GitHub\Web-Development\js-projects-2
#
# Processing: poetrydb-flask-app
#   [WILL UPDATE] URL to: https://github.com/k26rahul/poetrydb-flask-app.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/poetrydb-flask-app.git inside C:\k26rahul\Code\GitHub\Web-Development\poetrydb-flask-app
#
# Processing: poster-catalogue-app
#   [WILL UPDATE] URL to: https://github.com/k26rahul/poster-catalogue-app.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/poster-catalogue-app.git inside C:\k26rahul\Code\GitHub\Web-Development\poster-catalogue-app
#
# Processing: fastapi-postgresql-basics
#   [WILL UPDATE] URL to: https://github.com/k26rahul/fastapi-postgresql-basics.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/fastapi-postgresql-basics.git inside C:\k26rahul\Code\GitHub\Web-Development\fastapi-postgresql-basics
#
# Processing: react-egghead-course
#   [WILL UPDATE] URL to: https://github.com/k26rahul/react-egghead-course.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/react-egghead-course.git inside C:\k26rahul\Code\GitHub\Web-Development\react-egghead-course
#
# Processing: react-egghead-course-2
#   [WILL UPDATE] URL to: https://github.com/k26rahul/react-egghead-course-2.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/react-egghead-course-2.git inside C:\k26rahul\Code\GitHub\Web-Development\react-egghead-course-2
#
# Processing: tic-tac-toe-vanilla-js-2025
#   [WILL UPDATE] URL to: https://github.com/k26rahul/tic-tac-toe-vanilla-js-2025.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/tic-tac-toe-vanilla-js-2025.git inside C:\k26rahul\Code\GitHub\Web-Development\tic-tac-toe-vanilla-js-2025
#
# Processing: tic-tac-toe-react
#   [WILL UPDATE] URL to: https://github.com/k26rahul/tic-tac-toe-react.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/tic-tac-toe-react.git inside C:\k26rahul\Code\GitHub\Web-Development\tic-tac-toe-react
#
# Processing: tic-tac-toe-vanilla-js
#   [WILL UPDATE] URL to: https://github.com/k26rahul/tic-tac-toe-vanilla-js.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/tic-tac-toe-vanilla-js.git inside C:\k26rahul\Code\GitHub\Web-Development\tic-tac-toe-vanilla-js
#
# Processing: plotly-vector-visualizer
#   [WILL UPDATE] URL to: https://github.com/k26rahul/plotly-vector-visualizer.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/plotly-vector-visualizer.git inside C:\k26rahul\Code\GitHub\Web-Development\plotly-vector-visualizer
#
# Processing: remotion-story-video
#   [WILL UPDATE] URL to: https://github.com/k26rahul/remotion-story-video.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/remotion-story-video.git inside C:\k26rahul\Code\GitHub\Web-Development\remotion-story-video
#
# Processing: weather-app-react
#   [WILL UPDATE] URL to: https://github.com/k26rahul/weather-app-react.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/weather-app-react.git inside C:\k26rahul\Code\GitHub\Web-Development\weather-app-react
#
# Processing: boston-housing-price-prediction
#   [WILL UPDATE] URL to: https://github.com/k26rahul/boston-housing-price-prediction.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/boston-housing-price-prediction.git inside C:\k26rahul\Code\GitHub\Machine-Learning\boston-housing-price-prediction
#
# Processing: deep-learning-march-2024
#   [WILL UPDATE] URL to: https://github.com/k26rahul/deep-learning-march-2024.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/deep-learning-march-2024.git inside C:\k26rahul\Code\GitHub\Machine-Learning\deep-learning-march-2024
#
# Processing: machine-learning-april-2023
#   [WILL UPDATE] URL to: https://github.com/k26rahul/machine-learning-april-2023.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/machine-learning-april-2023.git inside C:\k26rahul\Code\GitHub\Machine-Learning\machine-learning-april-2023
#
# Processing: machine-learning-kylie-ying
#   [WILL UPDATE] URL to: https://github.com/k26rahul/machine-learning-kylie-ying.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/machine-learning-kylie-ying.git inside C:\k26rahul\Code\GitHub\Machine-Learning\machine-learning-kylie-ying
#
# Processing: machine-learning-april-2025
#   [WILL UPDATE] URL to: https://github.com/k26rahul/machine-learning-april-2025.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/machine-learning-april-2025.git inside C:\k26rahul\Code\GitHub\Machine-Learning\machine-learning-april-2025
#
# Processing: machine-learning-march-2024
#   [WILL UPDATE] URL to: https://github.com/k26rahul/machine-learning-march-2024.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/machine-learning-march-2024.git inside C:\k26rahul\Code\GitHub\Machine-Learning\machine-learning-march-2024
#
# Processing: ml-projects-siddhardhan
#   [WILL UPDATE] URL to: https://github.com/k26rahul/ml-projects-siddhardhan.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/ml-projects-siddhardhan.git inside C:\k26rahul\Code\GitHub\Machine-Learning\ml-projects-siddhardhan
#
# Processing: ipl2023-powerplay-score-prediction
#   [WILL UPDATE] URL to: https://github.com/k26rahul/ipl2023-powerplay-score-prediction.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/ipl2023-powerplay-score-prediction.git inside C:\k26rahul\Code\GitHub\Machine-Learning\ipl2023-powerplay-score-prediction
#
# Processing: codeforces-december-2023
#   [WILL UPDATE] URL to: https://github.com/k26rahul/codeforces-december-2023.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/codeforces-december-2023.git inside C:\k26rahul\Code\GitHub\DSA\codeforces-december-2023
#
# Processing: dsa-cp
#   [WILL UPDATE] URL to: https://github.com/k26rahul/dsa-cp.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/dsa-cp.git inside C:\k26rahul\Code\GitHub\DSA\dsa-cp
#
# Processing: dsa-java-march-2024
#   [WILL UPDATE] URL to: https://github.com/k26rahul/dsa-java-march-2024.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/dsa-java-march-2024.git inside C:\k26rahul\Code\GitHub\DSA\dsa-java-march-2024
#
# Processing: dsa-java-september-2024
#   [WILL UPDATE] URL to: https://github.com/k26rahul/dsa-java-september-2024.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/dsa-java-september-2024.git inside C:\k26rahul\Code\GitHub\DSA\dsa-java-september-2024
#
# Processing: mosh-ultimate-dsa-java
#   [WILL UPDATE] URL to: https://github.com/k26rahul/mosh-ultimate-dsa-java.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/mosh-ultimate-dsa-java.git inside C:\k26rahul\Code\GitHub\DSA\mosh-ultimate-dsa-java
#
# Processing: mad1-coursework
#   [WILL UPDATE] URL to: https://github.com/k26rahul/mad1-coursework.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/mad1-coursework.git inside C:\k26rahul\Code\GitHub\IITM\mad1-coursework
#
# Processing: mad1-course-website
#   [WILL UPDATE] URL to: https://github.com/k26rahul/mad1-course-website.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/mad1-course-website.git inside C:\k26rahul\Code\GitHub\IITM\mad1-course-website
#
# Processing: mad2-coursework
#   [WILL UPDATE] URL to: https://github.com/k26rahul/mad2-coursework.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/mad2-coursework.git inside C:\k26rahul\Code\GitHub\IITM\mad2-coursework
#
# Processing: machine-learning-techniques
#   [WILL UPDATE] URL to: https://github.com/k26rahul/machine-learning-techniques.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/machine-learning-techniques.git inside C:\k26rahul\Code\GitHub\IITM\machine-learning-techniques
#
# Processing: dbms-t3-2023
#   [WILL UPDATE] URL to: https://github.com/k26rahul/dbms-t3-2023.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/dbms-t3-2023.git inside C:\k26rahul\Code\GitHub\IITM\dbms-t3-2023
#
# Processing: dbms-t1-2024
#   [WILL UPDATE] URL to: https://github.com/k26rahul/dbms-t1-2024.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/dbms-t1-2024.git inside C:\k26rahul\Code\GitHub\IITM\dbms-t1-2024
#
# Processing: dbms-t2-2024
#   [WILL UPDATE] URL to: https://github.com/k26rahul/dbms-t2-2024.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/dbms-t2-2024.git inside C:\k26rahul\Code\GitHub\IITM\dbms-t2-2024
#
# Processing: mad1-project
#   [WILL UPDATE] URL to: https://github.com/k26rahul/mad1-project.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/mad1-project.git inside C:\k26rahul\Code\GitHub\IITM\mad1-project
#
# Processing: mad1-project-skeleton
#   [WILL UPDATE] URL to: https://github.com/k26rahul/mad1-project-skeleton.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/mad1-project-skeleton.git inside C:\k26rahul\Code\GitHub\IITM\mad1-project-skeleton
#
# Processing: mad1-project-prototype
#   [WILL UPDATE] URL to: https://github.com/k26rahul/mad1-project-prototype.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/mad1-project-prototype.git inside C:\k26rahul\Code\GitHub\IITM\mad1-project-prototype
#
# Processing: flask-sqlalchemy-template
#   [WILL UPDATE] URL to: https://github.com/k26rahul/flask-sqlalchemy-template.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/flask-sqlalchemy-template.git inside C:\k26rahul\Code\GitHub\IITM\flask-sqlalchemy-template
#
# Processing: mad2-project
#   [WILL UPDATE] URL to: https://github.com/k26rahul/mad2-project.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/mad2-project.git inside C:\k26rahul\Code\GitHub\IITM\mad2-project
#
# Processing: mad2-project-skeleton
#   [WILL UPDATE] URL to: https://github.com/k26rahul/mad2-project-skeleton.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/mad2-project-skeleton.git inside C:\k26rahul\Code\GitHub\IITM\mad2-project-skeleton
#
# Processing: java-t1-2024
#   [WILL UPDATE] URL to: https://github.com/k26rahul/java-t1-2024.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/java-t1-2024.git inside C:\k26rahul\Code\GitHub\IITM\java-t1-2024
#
# Processing: java-t1-2025
#   [WILL UPDATE] URL to: https://github.com/k26rahul/java-t1-2025.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/java-t1-2025.git inside C:\k26rahul\Code\GitHub\IITM\java-t1-2025
#
# Processing: java-t2-2025
#   [WILL UPDATE] URL to: https://github.com/k26rahul/java-t2-2025.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/java-t2-2025.git inside C:\k26rahul\Code\GitHub\IITM\java-t2-2025
#
# Processing: pdsa-t1-2024
#   [WILL UPDATE] URL to: https://github.com/k26rahul/pdsa-t1-2024.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/pdsa-t1-2024.git inside C:\k26rahul\Code\GitHub\IITM\pdsa-t1-2024
#
# Processing: pdsa-t2-2024
#   [WILL UPDATE] URL to: https://github.com/k26rahul/pdsa-t2-2024.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/pdsa-t2-2024.git inside C:\k26rahul\Code\GitHub\IITM\pdsa-t2-2024
#
# Processing: python-t2-2023
#   [WILL UPDATE] URL to: https://github.com/k26rahul/python-t2-2023.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/python-t2-2023.git inside C:\k26rahul\Code\GitHub\IITM\python-t2-2023
#
# Processing: python-t1-2024
#   [WILL UPDATE] URL to: https://github.com/k26rahul/python-t1-2024.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/python-t1-2024.git inside C:\k26rahul\Code\GitHub\IITM\python-t1-2024
#
# Processing: python-oppe1-t3-2023
#   [WILL UPDATE] URL to: https://github.com/k26rahul/python-oppe1-t3-2023.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/python-oppe1-t3-2023.git inside C:\k26rahul\Code\GitHub\IITM\python-oppe1-t3-2023
#
# Processing: python-oppe2-t3-2023
#   [WILL UPDATE] URL to: https://github.com/k26rahul/python-oppe2-t3-2023.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/python-oppe2-t3-2023.git inside C:\k26rahul\Code\GitHub\IITM\python-oppe2-t3-2023
#
# Processing: k26rahul
#   [WILL UPDATE] URL to: https://github.com/k26rahul/k26rahul.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/k26rahul.git inside C:\k26rahul\Code\GitHub\Others\k26rahul
#
# Processing: playground-2024
#   [WILL UPDATE] URL to: https://github.com/k26rahul/playground-2024.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/playground-2024.git inside C:\k26rahul\Code\GitHub\Others\playground-2024
#
# Processing: playground-2025
#   [WILL UPDATE] URL to: https://github.com/k26rahul/playground-2025.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/playground-2025.git inside C:\k26rahul\Code\GitHub\Others\playground-2025
#
# Processing: yt-channel-downloader
#   [WILL UPDATE] URL to: https://github.com/k26rahul/yt-channel-downloader.git
#   [WILL EXECUTE] git remote set-url origin https://github.com/k26rahul/yt-channel-downloader.git inside C:\k26rahul\Code\GitHub\Others\yt-channel-downloader
#
# All remote URLs processed.
